# %% [markdown]
# ## IPL 2025

# %%
# Importing the python labraries for data analysis

import pandas as pd    # for data manipulation 
import numpy as np     # for numerical operation
import os 
import seaborn as sns   # for prettier graphs
import matplotlib.pyplot as plt # for plotting graphs

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hp\\Dropbox\\PC\\Downloads'

# %%
os.chdir('C:\\Users\\Hp\\Dropbox\\PC\\Downloads')

# %%
df=pd.read_csv('matches.csv') #importing the file

# %%
df.head() # shows first 5 rows
# Out:
#    match_id           date                                          venue  \
# 0         1  March 22,2025                          Eden Gardens, Kolkata
# 1         2  March 23,2025  Rajiv Gandhi International Stadium, Hyderabad
# 2         3  March 23,2025                MA Chidambaram Stadium, Chennai
# 3         4  March 24,2025       ACA-VDCA Cricket Stadium, Vishakhapatnam
# 4         5  March 25,2025               Narendra Modi Stadium, Ahmedabad
#
#   team1 team2   stage toss_winner toss_decision  first_ings_score  \
# 0   KKR   RCB  League         RCB          Bowl             174.0
# 1   SRH    RR  League          RR          Bowl             286.0
# 2   CSK    MI  League         CSK          Bowl             155.0
# 3    DC   LSG  League          DC          Bowl             209.0
# 4    GT  PBKS  League          GT          Bowl             243.0
#
#    first_ings_wkts  ...  match_result  match_winner wb_runs wb_wickets  \
# ...

# %%
df.shape
# Out:
# (74, 22)

# %%
df.info() # check columns, data types and nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          73 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     73 non-null     float64
#  9   first_ings_wkts      73 non-null     float64
#  10  second_ings_score    72 non-null     float64
#  11  second_ings_wkts     72 non-null     float64
#  12  match_result         74 non-null     object
#  13  match_winner         71 non-null     object
#  14  wb_runs              34 non-null     object
# ...

# %%
# In this data set has some null value like wb_run and wb_wickets has more null value

# %%
df2 = df.drop('match_id',axis=1) #dropped the match id from the data set

# %%
df2.columns # see all the  columns names
# Out:
# Index(['date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_result', 'match_winner',
#        'wb_runs', 'wb_wickets', 'balls_left', 'player_of_the_match',
#        'top_scorer', 'highscore', 'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
df2.describe().T  # summary stats for numeric columns
# Out:
#                    count        mean        std   min    25%    50%     75%  \
# first_ings_score    73.0  189.753425  37.489547  95.0  166.0  196.0  213.00
# first_ings_wkts     73.0    6.452055   2.108456   2.0    5.0    6.0    8.00
# second_ings_score   72.0  174.013889  38.805217   7.0  158.0  177.0  201.25
# second_ings_wkts    72.0    5.513889   2.882649   0.0    3.0    5.0    8.00
# balls_left          72.0   10.819444  17.674942   0.0    0.0    5.5   13.50
# highscore           71.0   74.549296  20.088226  37.0   61.0   73.0   88.50
#
#                      max
# first_ings_score   286.0
# first_ings_wkts     10.0
# second_ings_score  247.0
# second_ings_wkts    10.0
# balls_left         114.0
# highscore          141.0

# %%
df2.shape # checks number of rows and columns in the data set
# Out:
# (74, 21)

# %%
df2.isnull().sum()
# Out:
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            1
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        1
# second_ings_score      0
# second_ings_wkts       2
# match_result           0
# match_winner           0
# wb_runs                0
# wb_wickets             0
# balls_left             0
# player_of_the_match    0
# top_scorer             3
# highscore              0
# best_bowling           3
# best_bowling_figure    3
# dtype: int64

# %%
df2.head(2)
# Out:
#             date                                          venue team1 team2  \
# 0  March 22,2025                          Eden Gardens, Kolkata   KKR   RCB
# 1  March 23,2025  Rajiv Gandhi International Stadium, Hyderabad   SRH    RR
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 0  League         RCB          Bowl             174.0              8.0
# 1  League          RR          Bowl             286.0              6.0
#
#    second_ings_score  ...  match_result match_winner wb_runs wb_wickets  \
# 0              177.0  ...     completed          RCB     NaN          7
# 1              242.0  ...     completed          SRH      44        NaN
#
#   balls_left  player_of_the_match    top_scorer highscore      best_bowling  \
# 0       22.0        Krunal Pandya   Virat Kohli      59.0     Krunal Pandya
# 1        0.0         Ishan Kishan  Ishan Kishan     106.0  Tushar Deshpande
#
#   best_bowling_figure
# 0               3--29
# ...

# %%
# Dealing with the null value

# %%
df2['match_winner'].fillna('Unknown', inplace=True)
df2['wb_runs'].fillna(0, inplace=True)
df2['wb_wickets'].fillna(0, inplace=True)
df2['player_of_the_match'].fillna('No Award', inplace=True)
df2['first_ings_score'].fillna(0, inplace=True)
df2['balls_left'].fillna(0, inplace=True)
df2['first_ings_score'].fillna(0, inplace=True)
df2['second_ings_score'].fillna(0, inplace=True)
df2['highscore'].fillna(0, inplace=True)
df2['toss_decision'].fillna(df['toss_decision'].mode()[0], inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14204\533651889.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['first_ings_score'].fillna(0, inplace=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14204\533651889.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 74 non-null     object
#  1   venue                74 non-null     object
#  2   team1                74 non-null     object
#  3   team2                74 non-null     object
#  4   stage                74 non-null     object
#  5   toss_winner          73 non-null     object
#  6   toss_decision        74 non-null     object
#  7   first_ings_score     74 non-null     float64
#  8   first_ings_wkts      73 non-null     float64
#  9   second_ings_score    74 non-null     float64
#  10  second_ings_wkts     72 non-null     float64
#  11  match_result         74 non-null     object
#  12  match_winner         74 non-null     object
#  13  wb_runs              74 non-null     object
#  14  wb_wickets           74 non-null     object
# ...

# %%
df2.head(2)
# Out:
#             date                                          venue team1 team2  \
# 0  March 22,2025                          Eden Gardens, Kolkata   KKR   RCB
# 1  March 23,2025  Rajiv Gandhi International Stadium, Hyderabad   SRH    RR
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 0  League         RCB          Bowl             174.0              8.0
# 1  League          RR          Bowl             286.0              6.0
#
#    second_ings_score  ...  match_result match_winner wb_runs wb_wickets  \
# 0              177.0  ...     completed          RCB       0          7
# 1              242.0  ...     completed          SRH      44          0
#
#   balls_left  player_of_the_match    top_scorer highscore      best_bowling  \
# 0       22.0        Krunal Pandya   Virat Kohli      59.0     Krunal Pandya
# 1        0.0         Ishan Kishan  Ishan Kishan     106.0  Tushar Deshpande
#
#   best_bowling_figure
# 0               3--29
# ...

# %% [markdown]
# ### 1. How many matches were played at each venue?

# %%
df2['venue'].value_counts().plot(kind='bar',figsize=(10,5))
plt.title('Matches per Venue')
plt.xlabel('Venue')
plt.ylabel('Number of matches')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 2.Matches Played by the teams

# %%
matches_played=df2['team1'].value_counts().add(df2['team2'].value_counts(),fill_value=0).reset_index()
matches_played.columns=['team','matches_played']
matches_played
# Out:
#    team  matches_played
# 0   CSK              14
# 1    DC              14
# 2    GT              15
# 3   KKR              14
# 4   LSG              14
# 5    MI              16
# 6  PBKS              17
# 7   RCB              16
# 8    RR              14
# 9   SRH              14

# %% [markdown]
# ## 3. Who won the most tosses?

# %%
df2['toss_winner'].value_counts().plot(kind='bar',color='yellow')
plt.title('Toss Wins By Team')
plt.show()

# %% [markdown]
# ## 4. Match winners and frequency

# %%
df2['match_winner'].value_counts().head(10).plot(kind='bar',color='green')
plt.title('Top Match Winners')
plt.show()

# %% [markdown]
# ## 5. Correlation Between Runs & Wickets

# %%
df2.columns
# Out:
# Index(['date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_result', 'match_winner',
#        'wb_runs', 'wb_wickets', 'balls_left', 'player_of_the_match',
#        'top_scorer', 'highscore', 'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
sns.scatterplot(x='first_ings_score', y='first_ings_wkts',data=df2)
plt.title('1st Innings: Score vs Wickets')
plt.show()

# %%
sns.scatterplot(x='second_ings_score', y='second_ings_wkts',data=df2)
plt.title('2nd Innings: Score vs Wickets')
plt.show()

# %% [markdown]
# ## 6. Most frequent "Player of the match"

# %%
top_players=df['player_of_the_match'].value_counts().head(10)

top_players.plot(kind='bar',color='pink')
plt.title('Top 10 Player of the match winners')
plt.ylabel('No. of Awards')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 7. Top Scorers and Their Highest Scores

# %%
top_scorers=df2.groupby('top_scorer')['highscore'].max().sort_values(ascending=False).head(10)

top_scorers.plot(kind='barh',color='red')
plt.title('Top 10 Highest individual Scores')
plt.xlabel('Runs')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## 8. Toss decision impact on match result

# %%
toss_result_df=df2.dropna(subset=['match_winner','toss_winner'])

toss_result_df['toss_win_and_match_win']=np.where(
    toss_result_df['toss_winner']==toss_result_df['match_winner'],
    'Yes','No'
)

sns.countplot(x='toss_win_and_match_win', hue='toss_decision',data=toss_result_df)
plt.title('Did toss winner also win the match')
plt.xlabel('Toss Winner' == 'Match Winner')
plt.ylabel('Match Count')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14204\263911564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toss_result_df['toss_win_and_match_win']=np.where(

# %% [markdown]
# ## 9. Highest Match Aggregates (Total runs in both innings)

# %%
df2['total_runs'] = df2['first_ings_score'] + df2['second_ings_score']
top_matches = df2.sort_values(by='total_runs', ascending=False).head(10)


print(top_matches[['team1', 'team2', 'first_ings_score', 'second_ings_score', 'total_runs']])
# Out:
#    team1 team2  first_ings_score  second_ings_score  total_runs
# 1    SRH    RR             286.0              242.0       528.0
# 26   SRH  PBKS             245.0              247.0       492.0
# 4     GT  PBKS             243.0              232.0       475.0
# 20   KKR   LSG             238.0              234.0       472.0
# 69   LSG   RCB             227.0              230.0       457.0
# 67   KKR   SRH             278.0              168.0       446.0
# 63    GT   LSG             235.0              202.0       437.0
# 71    GT    MI             228.0              208.0       436.0
# 53  PBKS   LSG             236.0              199.0       435.0
# 19    MI   RCB             221.0              209.0       430.0

# %% [markdown]
# ## 10. winning by High score vs wickets

# %%
print("Wins by Runs:", df['wb_runs'].notnull().sum())
print("Wins by Wickets:", df['wb_wickets'].notnull().sum())


df['win_type'] = np.where(df['wb_runs'].notnull(), 'By Runs',
                   np.where(df['wb_wickets'].notnull(), 'By Wickets', 'Unknown'))


sns.countplot(x='win_type', data=df)
plt.title('How were matches won?')
plt.show()
# Out:
# Wins by Runs: 34
# Wins by Wickets: 38
